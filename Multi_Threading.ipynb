# %%
import multiprocessing, threading, numpy as np, os, sys, time, threading, multiprocessing, random as r

# %%
numberOfCores = multiprocessing.cpu_count()
print ("Num of cores are: ", numberOfCores)
# Out:
# Num of cores are:  2

# %%
startTime = time.time()

# %%
def matrix_multiply(matrix, constant_matrix, result, index):

    # Check if matrices are compatible for multiplication
    if len(matrix[0]) != len(constant_matrix):
        raise ValueError("Matrices are not compatible for multiplication.")

    # Initialize result matrix with zeros
    temp = [[0 for _ in range(len(constant_matrix[0]))] for _ in range(len(matrix))]

    # Perform matrix multiplication
    for i in range(len(matrix)):
        for j in range(len(constant_matrix[0])):
            for k in range(len(constant_matrix)):
                temp[i][j] += matrix[i][k] * constant_matrix[k][j]

    result[index] = temp

# %%
matrices = [np.random.rand(100, 100) for _ in range(100)]
constant_matrix = np.random.rand(100, 100)

# %%
timelist=[]
for k in range(1,12):
    startTime = time.time()
    results = [None] * 100

    num_threads = k


    activeThreads = threading.activeCount()
    print ("Num of threads: ",activeThreads)



    for i in range(100):

        # This Creates a sing thread
        t = threading.Thread(target=matrix_multiply, args=(matrices[i], constant_matrix, results, i))
        t.start() # This starts the execution of the thread

        print("Multiplying matrix %d"%(i+1))

        # Wait until the number of active threads becomes less than or equal to the specified number
        while True:
            if threading.active_count() - activeThreads < num_threads:
                break
            time.sleep(1)


    cmd = 'Sample task'


    time.sleep(1)
    # Waiting to finish all Threads
    while True:
        if threading.activeCount() == activeThreads:
            break
        else:
            print ("    Thread still running (left %d)..."%(threading.activeCount() - activeThreads))
            time.sleep(1)

    print(" All Thread ends")

    print("Total Time %f sec" % (round( time.time() - startTime,4)))
    timelist.append((round( time.time() - startTime,4)))
# Out:
# <ipython-input-6-e26b1243a0af>:9: DeprecationWarning: activeCount() is deprecated, use active_count() instead
#   activeThreads = threading.activeCount()
# Num of threads:  5
# Multiplying matrix 1
# Multiplying matrix 2
# Multiplying matrix 3
# Multiplying matrix 4
# Multiplying matrix 5
# Multiplying matrix 6
# Multiplying matrix 7
# Multiplying matrix 8
# Multiplying matrix 9
# Multiplying matrix 10
# Multiplying matrix 11
# Multiplying matrix 12
# Multiplying matrix 13
# Multiplying matrix 14
# Multiplying matrix 15
# Multiplying matrix 16
# Multiplying matrix 17
# Multiplying matrix 18
# Multiplying matrix 19
# Multiplying matrix 20
# Multiplying matrix 21
# Multiplying matrix 22
# Multiplying matrix 23
# Multiplying matrix 24
# Multiplying matrix 25
# Multiplying matrix 26
# Multiplying matrix 27
# Multiplying matrix 28
# Multiplying matrix 29
# Multiplying matrix 30
# Multiplying matrix 31
# Multiplying matrix 32
# Multiplying matrix 33
# Multiplying matrix 34
# Multiplying matrix 35
# Multiplying matrix 36
# Multiplying matrix 37
# Multiplying matrix 38
# Multiplying matrix 39
# Multiplying matrix 40
# Multiplying matrix 41
# Multiplying matrix 42
# Multiplying matrix 43
# Multiplying matrix 44
# Multiplying matrix 45
# Multiplying matrix 46
# Multiplying matrix 47
# Multiplying matrix 48
# Multiplying matrix 49
# Multiplying matrix 50
# Multiplying matrix 51
# Multiplying matrix 52
# Multiplying matrix 53
# Multiplying matrix 54
# Multiplying matrix 55
# Multiplying matrix 56
# Multiplying matrix 57
# Multiplying matrix 58
# Multiplying matrix 59
# Multiplying matrix 60
# Multiplying matrix 61
# Multiplying matrix 62
# Multiplying matrix 63
# Multiplying matrix 64
# Multiplying matrix 65
# Multiplying matrix 66
# Multiplying matrix 67
# Multiplying matrix 68
# Multiplying matrix 69
# Multiplying matrix 70
# Multiplying matrix 71
# Multiplying matrix 72
# Multiplying matrix 73
# Multiplying matrix 74
# Multiplying matrix 75
# Multiplying matrix 76
# Multiplying matrix 77
# Multiplying matrix 78
# Multiplying matrix 79
# Multiplying matrix 80
# Multiplying matrix 81
# Multiplying matrix 82
# Multiplying matrix 83
# Multiplying matrix 84
# Multiplying matrix 85
# Multiplying matrix 86
# Multiplying matrix 87
# Multiplying matrix 88
# Multiplying matrix 89
# Multiplying matrix 90
# Multiplying matrix 91
# Multiplying matrix 92
# Multiplying matrix 93
# Multiplying matrix 94
# Multiplying matrix 95
# Multiplying matrix 96
# Multiplying matrix 97
# Multiplying matrix 98
# Multiplying matrix 99
# Multiplying matrix 100
# <ipython-input-6-e26b1243a0af>:35: DeprecationWarning: activeCount() is deprecated, use active_count() instead
#   if threading.activeCount() == activeThreads:
#  All Thread ends
# Total Time 111.336900 sec
# Num of threads:  5
# Multiplying matrix 1
# Multiplying matrix 2
# Multiplying matrix 3
# Multiplying matrix 4
# Multiplying matrix 5
# Multiplying matrix 6
# Multiplying matrix 7
# Multiplying matrix 8
# Multiplying matrix 9
# Multiplying matrix 10
# Multiplying matrix 11
# Multiplying matrix 12
# Multiplying matrix 13
# Multiplying matrix 14
# Multiplying matrix 15
# Multiplying matrix 16
# Multiplying matrix 17
# Multiplying matrix 18
# Multiplying matrix 19
# Multiplying matrix 20
# Multiplying matrix 21
# Multiplying matrix 22
# Multiplying matrix 23
# Multiplying matrix 24
# Multiplying matrix 25
# Multiplying matrix 26
# Multiplying matrix 27
# Multiplying matrix 28
# Multiplying matrix 29
# Multiplying matrix 30
# Multiplying matrix 31
# Multiplying matrix 32
# Multiplying matrix 33
# Multiplying matrix 34
# Multiplying matrix 35
# Multiplying matrix 36
# Multiplying matrix 37
# Multiplying matrix 38
# Multiplying matrix 39
# Multiplying matrix 40
# Multiplying matrix 41
# Multiplying matrix 42
# Multiplying matrix 43
# Multiplying matrix 44
# Multiplying matrix 45
# Multiplying matrix 46
# Multiplying matrix 47
# Multiplying matrix 48
# Multiplying matrix 49
# Multiplying matrix 50
# Multiplying matrix 51
# Multiplying matrix 52
# Multiplying matrix 53
# Multiplying matrix 54
# Multiplying matrix 55
# Multiplying matrix 56
# Multiplying matrix 57
# Multiplying matrix 58
# Multiplying matrix 59
# Multiplying matrix 60
# Multiplying matrix 61
# Multiplying matrix 62
# Multiplying matrix 63
# Multiplying matrix 64
# Multiplying matrix 65
# Multiplying matrix 66
# Multiplying matrix 67
# Multiplying matrix 68
# Multiplying matrix 69
# Multiplying matrix 70
# Multiplying matrix 71
# Multiplying matrix 72
# Multiplying matrix 73
# Multiplying matrix 74
# Multiplying matrix 75
# Multiplying matrix 76
# Multiplying matrix 77
# Multiplying matrix 78
# Multiplying matrix 79
# Multiplying matrix 80
# Multiplying matrix 81
# Multiplying matrix 82
# Multiplying matrix 83
# Multiplying matrix 84
# Multiplying matrix 85
# Multiplying matrix 86
# Multiplying matrix 87
# Multiplying matrix 88
# Multiplying matrix 89
# Multiplying matrix 90
# Multiplying matrix 91
# Multiplying matrix 92
# Multiplying matrix 93
# Multiplying matrix 94
# Multiplying matrix 95
# Multiplying matrix 96
# Multiplying matrix 97
# Multiplying matrix 98
# Multiplying matrix 99
# Multiplying matrix 100
#  All Thread ends
# Total Time 106.331000 sec
# Num of threads:  5
# Multiplying matrix 1
# Multiplying matrix 2
# Multiplying matrix 3
# Multiplying matrix 4
# Multiplying matrix 5
# Multiplying matrix 6
# Multiplying matrix 7
# Multiplying matrix 8
# Multiplying matrix 9
# Multiplying matrix 10
# Multiplying matrix 11
# Multiplying matrix 12
# Multiplying matrix 13
# Multiplying matrix 14
# Multiplying matrix 15
# Multiplying matrix 16
# Multiplying matrix 17
# Multiplying matrix 18
# Multiplying matrix 19
# Multiplying matrix 20
# Multiplying matrix 21
# Multiplying matrix 22
# Multiplying matrix 23
# Multiplying matrix 24
# Multiplying matrix 25
# Multiplying matrix 26
# Multiplying matrix 27
# Multiplying matrix 28
# Multiplying matrix 29
# Multiplying matrix 30
# Multiplying matrix 31
# Multiplying matrix 32
# Multiplying matrix 33
# Multiplying matrix 34
# Multiplying matrix 35
# Multiplying matrix 36
# Multiplying matrix 37
# Multiplying matrix 38
# Multiplying matrix 39
# Multiplying matrix 40
# Multiplying matrix 41
# Multiplying matrix 42
# Multiplying matrix 43
# Multiplying matrix 44
# Multiplying matrix 45
# Multiplying matrix 46
# Multiplying matrix 47
# Multiplying matrix 48
# Multiplying matrix 49
# Multiplying matrix 50
# Multiplying matrix 51
# Multiplying matrix 52
# Multiplying matrix 53
# Multiplying matrix 54
# Multiplying matrix 55
# Multiplying matrix 56
# Multiplying matrix 57
# Multiplying matrix 58
# Multiplying matrix 59
# Multiplying matrix 60
# Multiplying matrix 61
# Multiplying matrix 62
# Multiplying matrix 63
# Multiplying matrix 64
# Multiplying matrix 65
# Multiplying matrix 66
# Multiplying matrix 67
# Multiplying matrix 68
# Multiplying matrix 69
# Multiplying matrix 70
# Multiplying matrix 71
# Multiplying matrix 72
# Multiplying matrix 73
# Multiplying matrix 74
# Multiplying matrix 75
# Multiplying matrix 76
# Multiplying matrix 77
# Multiplying matrix 78
# Multiplying matrix 79
# Multiplying matrix 80
# Multiplying matrix 81
# Multiplying matrix 82
# Multiplying matrix 83
# Multiplying matrix 84
# Multiplying matrix 85
# Multiplying matrix 86
# Multiplying matrix 87
# Multiplying matrix 88
# Multiplying matrix 89
# Multiplying matrix 90
# Multiplying matrix 91
# Multiplying matrix 92
# Multiplying matrix 93
# Multiplying matrix 94
# Multiplying matrix 95
# Multiplying matrix 96
# Multiplying matrix 97
# Multiplying matrix 98
# Multiplying matrix 99
# Multiplying matrix 100
# <ipython-input-6-e26b1243a0af>:38: DeprecationWarning: activeCount() is deprecated, use active_count() instead
#   print ("    Thread still running (left %d)..."%(threading.activeCount() - activeThreads))
#     Thread still running (left 1)...
#  All Thread ends
# Total Time 89.451300 sec
# Num of threads:  5
# Multiplying matrix 1
# Multiplying matrix 2
# Multiplying matrix 3
# Multiplying matrix 4
# Multiplying matrix 5
# Multiplying matrix 6
# Multiplying matrix 7
# Multiplying matrix 8
# Multiplying matrix 9
# Multiplying matrix 10
# Multiplying matrix 11
# Multiplying matrix 12
# Multiplying matrix 13
# Multiplying matrix 14
# Multiplying matrix 15
# Multiplying matrix 16
# Multiplying matrix 17
# Multiplying matrix 18
# Multiplying matrix 19
# Multiplying matrix 20
# Multiplying matrix 21
# Multiplying matrix 22
# Multiplying matrix 23
# Multiplying matrix 24
# Multiplying matrix 25
# Multiplying matrix 26
# Multiplying matrix 27
# Multiplying matrix 28
# Multiplying matrix 29
# Multiplying matrix 30
# Multiplying matrix 31
# Multiplying matrix 32
# Multiplying matrix 33
# Multiplying matrix 34
# Multiplying matrix 35
# Multiplying matrix 36
# Multiplying matrix 37
# Multiplying matrix 38
# Multiplying matrix 39
# Multiplying matrix 40
# Multiplying matrix 41
# Multiplying matrix 42
# Multiplying matrix 43
# Multiplying matrix 44
# Multiplying matrix 45
# Multiplying matrix 46
# Multiplying matrix 47
# Multiplying matrix 48
# Multiplying matrix 49
# Multiplying matrix 50
# Multiplying matrix 51
# Multiplying matrix 52
# Multiplying matrix 53
# Multiplying matrix 54
# Multiplying matrix 55
# Multiplying matrix 56
# Multiplying matrix 57
# Multiplying matrix 58
# Multiplying matrix 59
# Multiplying matrix 60
# Multiplying matrix 61
# Multiplying matrix 62
# Multiplying matrix 63
# Multiplying matrix 64
# Multiplying matrix 65
# Multiplying matrix 66
# Multiplying matrix 67
# Multiplying matrix 68
# Multiplying matrix 69
# Multiplying matrix 70
# Multiplying matrix 71
# Multiplying matrix 72
# Multiplying matrix 73
# Multiplying matrix 74
# Multiplying matrix 75
# Multiplying matrix 76
# Multiplying matrix 77
# Multiplying matrix 78
# Multiplying matrix 79
# Multiplying matrix 80
# Multiplying matrix 81
# Multiplying matrix 82
# Multiplying matrix 83
# Multiplying matrix 84
# Multiplying matrix 85
# Multiplying matrix 86
# Multiplying matrix 87
# Multiplying matrix 88
# Multiplying matrix 89
# Multiplying matrix 90
# Multiplying matrix 91
# Multiplying matrix 92
# Multiplying matrix 93
# Multiplying matrix 94
# Multiplying matrix 95
# Multiplying matrix 96
# Multiplying matrix 97
# Multiplying matrix 98
# Multiplying matrix 99
# Multiplying matrix 100
#     Thread still running (left 3)...
#  All Thread ends
# Total Time 85.063800 sec
# Num of threads:  5
# Multiplying matrix 1
# Multiplying matrix 2
# Multiplying matrix 3
# Multiplying matrix 4
# Multiplying matrix 5
# Multiplying matrix 6
# Multiplying matrix 7
# Multiplying matrix 8
# Multiplying matrix 9
# Multiplying matrix 10
# Multiplying matrix 11
# Multiplying matrix 12
# Multiplying matrix 13
# Multiplying matrix 14
# Multiplying matrix 15
# Multiplying matrix 16
# Multiplying matrix 17
# Multiplying matrix 18
# Multiplying matrix 19
# Multiplying matrix 20
# Multiplying matrix 21
# Multiplying matrix 22
# Multiplying matrix 23
# Multiplying matrix 24
# Multiplying matrix 25
# Multiplying matrix 26
# Multiplying matrix 27
# Multiplying matrix 28
# Multiplying matrix 29
# Multiplying matrix 30
# Multiplying matrix 31
# Multiplying matrix 32
# Multiplying matrix 33
# Multiplying matrix 34
# Multiplying matrix 35
# Multiplying matrix 36
# Multiplying matrix 37
# Multiplying matrix 38
# Multiplying matrix 39
# Multiplying matrix 40
# Multiplying matrix 41
# Multiplying matrix 42
# Multiplying matrix 43
# Multiplying matrix 44
# Multiplying matrix 45
# Multiplying matrix 46
# Multiplying matrix 47
# Multiplying matrix 48
# Multiplying matrix 49
# Multiplying matrix 50
# Multiplying matrix 51
# Multiplying matrix 52
# Multiplying matrix 53
# Multiplying matrix 54
# Multiplying matrix 55
# Multiplying matrix 56
# Multiplying matrix 57
# Multiplying matrix 58
# Multiplying matrix 59
# Multiplying matrix 60
# Multiplying matrix 61
# Multiplying matrix 62
# Multiplying matrix 63
# Multiplying matrix 64
# Multiplying matrix 65
# Multiplying matrix 66
# Multiplying matrix 67
# Multiplying matrix 68
# Multiplying matrix 69
# Multiplying matrix 70
# Multiplying matrix 71
# Multiplying matrix 72
# Multiplying matrix 73
# Multiplying matrix 74
# Multiplying matrix 75
# Multiplying matrix 76
# Multiplying matrix 77
# Multiplying matrix 78
# Multiplying matrix 79
# Multiplying matrix 80
# Multiplying matrix 81
# Multiplying matrix 82
# Multiplying matrix 83
# Multiplying matrix 84
# Multiplying matrix 85
# Multiplying matrix 86
# Multiplying matrix 87
# Multiplying matrix 88
# Multiplying matrix 89
# Multiplying matrix 90
# Multiplying matrix 91
# Multiplying matrix 92
# Multiplying matrix 93
# Multiplying matrix 94
# Multiplying matrix 95
# Multiplying matrix 96
# Multiplying matrix 97
# Multiplying matrix 98
# Multiplying matrix 99
# Multiplying matrix 100
#     Thread still running (left 3)...
#     Thread still running (left 2)...
#  All Thread ends
# Total Time 83.029600 sec
# Num of threads:  5
# Multiplying matrix 1
# Multiplying matrix 2
# Multiplying matrix 3
# Multiplying matrix 4
# Multiplying matrix 5
# Multiplying matrix 6
# Multiplying matrix 7
# Multiplying matrix 8
# Multiplying matrix 9
# Multiplying matrix 10
# Multiplying matrix 11
# Multiplying matrix 12
# Multiplying matrix 13
# Multiplying matrix 14
# Multiplying matrix 15
# Multiplying matrix 16
# Multiplying matrix 17
# Multiplying matrix 18
# Multiplying matrix 19
# Multiplying matrix 20
# Multiplying matrix 21
# Multiplying matrix 22
# Multiplying matrix 23
# Multiplying matrix 24
# Multiplying matrix 25
# Multiplying matrix 26
# Multiplying matrix 27
# Multiplying matrix 28
# Multiplying matrix 29
# Multiplying matrix 30
# Multiplying matrix 31
# Multiplying matrix 32
# Multiplying matrix 33
# Multiplying matrix 34
# Multiplying matrix 35
# Multiplying matrix 36
# Multiplying matrix 37
# Multiplying matrix 38
# Multiplying matrix 39
# Multiplying matrix 40
# Multiplying matrix 41
# Multiplying matrix 42
# Multiplying matrix 43
# Multiplying matrix 44
# Multiplying matrix 45
# Multiplying matrix 46
# Multiplying matrix 47
# Multiplying matrix 48
# Multiplying matrix 49
# Multiplying matrix 50
# Multiplying matrix 51
# Multiplying matrix 52
# Multiplying matrix 53
# Multiplying matrix 54
# Multiplying matrix 55
# Multiplying matrix 56
# Multiplying matrix 57
# Multiplying matrix 58
# Multiplying matrix 59
# Multiplying matrix 60
# Multiplying matrix 61
# Multiplying matrix 62
# Multiplying matrix 63
# Multiplying matrix 64
# Multiplying matrix 65
# Multiplying matrix 66
# Multiplying matrix 67
# Multiplying matrix 68
# Multiplying matrix 69
# Multiplying matrix 70
# Multiplying matrix 71
# Multiplying matrix 72
# Multiplying matrix 73
# Multiplying matrix 74
# Multiplying matrix 75
# Multiplying matrix 76
# Multiplying matrix 77
# Multiplying matrix 78
# Multiplying matrix 79
# Multiplying matrix 80
# Multiplying matrix 81
# Multiplying matrix 82
# Multiplying matrix 83
# Multiplying matrix 84
# Multiplying matrix 85
# Multiplying matrix 86
# Multiplying matrix 87
# Multiplying matrix 88
# Multiplying matrix 89
# Multiplying matrix 90
# Multiplying matrix 91
# Multiplying matrix 92
# Multiplying matrix 93
# Multiplying matrix 94
# Multiplying matrix 95
# Multiplying matrix 96
# Multiplying matrix 97
# Multiplying matrix 98
# Multiplying matrix 99
# Multiplying matrix 100
#     Thread still running (left 4)...
#     Thread still running (left 4)...
#  All Thread ends
# Total Time 80.583600 sec
# Num of threads:  5
# Multiplying matrix 1
# Multiplying matrix 2
# Multiplying matrix 3
# Multiplying matrix 4
# Multiplying matrix 5
# Multiplying matrix 6
# Multiplying matrix 7
# Multiplying matrix 8
# Multiplying matrix 9
# Multiplying matrix 10
# Multiplying matrix 11
# Multiplying matrix 12
# Multiplying matrix 13
# Multiplying matrix 14
# Multiplying matrix 15
# Multiplying matrix 16
# Multiplying matrix 17
# Multiplying matrix 18
# Multiplying matrix 19
# Multiplying matrix 20
# Multiplying matrix 21
# Multiplying matrix 22
# Multiplying matrix 23
# Multiplying matrix 24
# Multiplying matrix 25
# Multiplying matrix 26
# Multiplying matrix 27
# Multiplying matrix 28
# Multiplying matrix 29
# Multiplying matrix 30
# Multiplying matrix 31
# Multiplying matrix 32
# Multiplying matrix 33
# Multiplying matrix 34
# Multiplying matrix 35
# Multiplying matrix 36
# Multiplying matrix 37
# Multiplying matrix 38
# Multiplying matrix 39
# Multiplying matrix 40
# Multiplying matrix 41
# Multiplying matrix 42
# Multiplying matrix 43
# Multiplying matrix 44
# Multiplying matrix 45
# Multiplying matrix 46
# Multiplying matrix 47
# Multiplying matrix 48
# Multiplying matrix 49
# Multiplying matrix 50
# Multiplying matrix 51
# Multiplying matrix 52
# Multiplying matrix 53
# Multiplying matrix 54
# Multiplying matrix 55
# Multiplying matrix 56
# Multiplying matrix 57
# Multiplying matrix 58
# Multiplying matrix 59
# Multiplying matrix 60
# Multiplying matrix 61
# Multiplying matrix 62
# Multiplying matrix 63
# Multiplying matrix 64
# Multiplying matrix 65
# Multiplying matrix 66
# Multiplying matrix 67
# Multiplying matrix 68
# Multiplying matrix 69
# Multiplying matrix 70
# Multiplying matrix 71
# Multiplying matrix 72
# Multiplying matrix 73
# Multiplying matrix 74
# Multiplying matrix 75
# Multiplying matrix 76
# Multiplying matrix 77
# Multiplying matrix 78
# Multiplying matrix 79
# Multiplying matrix 80
# Multiplying matrix 81
# Multiplying matrix 82
# Multiplying matrix 83
# Multiplying matrix 84
# Multiplying matrix 85
# Multiplying matrix 86
# Multiplying matrix 87
# Multiplying matrix 88
# Multiplying matrix 89
# Multiplying matrix 90
# Multiplying matrix 91
# Multiplying matrix 92
# Multiplying matrix 93
# Multiplying matrix 94
# Multiplying matrix 95
# Multiplying matrix 96
# Multiplying matrix 97
# Multiplying matrix 98
# Multiplying matrix 99
# Multiplying matrix 100
#     Thread still running (left 5)...
#     Thread still running (left 1)...
#  All Thread ends
# Total Time 80.505300 sec
# Num of threads:  5
# Multiplying matrix 1
# Multiplying matrix 2
# Multiplying matrix 3
# Multiplying matrix 4
# Multiplying matrix 5
# Multiplying matrix 6
# Multiplying matrix 7
# Multiplying matrix 8
# Multiplying matrix 9
# Multiplying matrix 10
# Multiplying matrix 11
# Multiplying matrix 12
# Multiplying matrix 13
# Multiplying matrix 14
# Multiplying matrix 15
# Multiplying matrix 16
# Multiplying matrix 17
# Multiplying matrix 18
# Multiplying matrix 19
# Multiplying matrix 20
# Multiplying matrix 21
# Multiplying matrix 22
# Multiplying matrix 23
# Multiplying matrix 24
# Multiplying matrix 25
# Multiplying matrix 26
# Multiplying matrix 27
# Multiplying matrix 28
# Multiplying matrix 29
# Multiplying matrix 30
# Multiplying matrix 31
# Multiplying matrix 32
# Multiplying matrix 33
# Multiplying matrix 34
# Multiplying matrix 35
# Multiplying matrix 36
# Multiplying matrix 37
# Multiplying matrix 38
# Multiplying matrix 39
# Multiplying matrix 40
# Multiplying matrix 41
# Multiplying matrix 42
# Multiplying matrix 43
# Multiplying matrix 44
# Multiplying matrix 45
# Multiplying matrix 46
# Multiplying matrix 47
# Multiplying matrix 48
# Multiplying matrix 49
# Multiplying matrix 50
# Multiplying matrix 51
# Multiplying matrix 52
# Multiplying matrix 53
# Multiplying matrix 54
# Multiplying matrix 55
# Multiplying matrix 56
# Multiplying matrix 57
# Multiplying matrix 58
# Multiplying matrix 59
# Multiplying matrix 60
# Multiplying matrix 61
# Multiplying matrix 62
# Multiplying matrix 63
# Multiplying matrix 64
# Multiplying matrix 65
# Multiplying matrix 66
# Multiplying matrix 67
# Multiplying matrix 68
# Multiplying matrix 69
# Multiplying matrix 70
# Multiplying matrix 71
# Multiplying matrix 72
# Multiplying matrix 73
# Multiplying matrix 74
# Multiplying matrix 75
# Multiplying matrix 76
# Multiplying matrix 77
# Multiplying matrix 78
# Multiplying matrix 79
# Multiplying matrix 80
# Multiplying matrix 81
# Multiplying matrix 82
# Multiplying matrix 83
# Multiplying matrix 84
# Multiplying matrix 85
# Multiplying matrix 86
# Multiplying matrix 87
# Multiplying matrix 88
# Multiplying matrix 89
# Multiplying matrix 90
# Multiplying matrix 91
# Multiplying matrix 92
# Multiplying matrix 93
# Multiplying matrix 94
# Multiplying matrix 95
# Multiplying matrix 96
# Multiplying matrix 97
# Multiplying matrix 98
# Multiplying matrix 99
# Multiplying matrix 100
#     Thread still running (left 2)...
#  All Thread ends
# Total Time 80.814100 sec
# Num of threads:  5
# Multiplying matrix 1
# Multiplying matrix 2
# Multiplying matrix 3
# Multiplying matrix 4
# Multiplying matrix 5
# Multiplying matrix 6
# Multiplying matrix 7
# Multiplying matrix 8
# Multiplying matrix 9
# Multiplying matrix 10
# Multiplying matrix 11
# Multiplying matrix 12
# Multiplying matrix 13
# Multiplying matrix 14
# Multiplying matrix 15
# Multiplying matrix 16
# Multiplying matrix 17
# Multiplying matrix 18
# Multiplying matrix 19
# Multiplying matrix 20
# Multiplying matrix 21
# Multiplying matrix 22
# Multiplying matrix 23
# Multiplying matrix 24
# Multiplying matrix 25
# Multiplying matrix 26
# Multiplying matrix 27
# Multiplying matrix 28
# Multiplying matrix 29
# Multiplying matrix 30
# Multiplying matrix 31
# Multiplying matrix 32
# Multiplying matrix 33
# Multiplying matrix 34
# Multiplying matrix 35
# Multiplying matrix 36
# Multiplying matrix 37
# Multiplying matrix 38
# Multiplying matrix 39
# Multiplying matrix 40
# Multiplying matrix 41
# Multiplying matrix 42
# Multiplying matrix 43
# Multiplying matrix 44
# Multiplying matrix 45
# Multiplying matrix 46
# Multiplying matrix 47
# Multiplying matrix 48
# Multiplying matrix 49
# Multiplying matrix 50
# Multiplying matrix 51
# Multiplying matrix 52
# Multiplying matrix 53
# Multiplying matrix 54
# Multiplying matrix 55
# Multiplying matrix 56
# Multiplying matrix 57
# Multiplying matrix 58
# Multiplying matrix 59
# Multiplying matrix 60
# Multiplying matrix 61
# Multiplying matrix 62
# Multiplying matrix 63
# Multiplying matrix 64
# Multiplying matrix 65
# Multiplying matrix 66
# Multiplying matrix 67
# Multiplying matrix 68
# Multiplying matrix 69
# Multiplying matrix 70
# Multiplying matrix 71
# Multiplying matrix 72
# Multiplying matrix 73
# Multiplying matrix 74
# Multiplying matrix 75
# Multiplying matrix 76
# Multiplying matrix 77
# Multiplying matrix 78
# Multiplying matrix 79
# Multiplying matrix 80
# Multiplying matrix 81
# Multiplying matrix 82
# Multiplying matrix 83
# Multiplying matrix 84
# Multiplying matrix 85
# Multiplying matrix 86
# Multiplying matrix 87
# Multiplying matrix 88
# Multiplying matrix 89
# Multiplying matrix 90
# Multiplying matrix 91
# Multiplying matrix 92
# Multiplying matrix 93
# Multiplying matrix 94
# Multiplying matrix 95
# Multiplying matrix 96
# Multiplying matrix 97
# Multiplying matrix 98
# Multiplying matrix 99
# Multiplying matrix 100
#     Thread still running (left 7)...
#     Thread still running (left 2)...
#  All Thread ends
# Total Time 82.809700 sec
# Num of threads:  5
# Multiplying matrix 1
# Multiplying matrix 2
# Multiplying matrix 3
# Multiplying matrix 4
# Multiplying matrix 5
# Multiplying matrix 6
# Multiplying matrix 7
# Multiplying matrix 8
# Multiplying matrix 9
# Multiplying matrix 10
# Multiplying matrix 11
# Multiplying matrix 12
# Multiplying matrix 13
# Multiplying matrix 14
# Multiplying matrix 15
# Multiplying matrix 16
# Multiplying matrix 17
# Multiplying matrix 18
# Multiplying matrix 19
# Multiplying matrix 20
# Multiplying matrix 21
# Multiplying matrix 22
# Multiplying matrix 23
# Multiplying matrix 24
# Multiplying matrix 25
# Multiplying matrix 26
# Multiplying matrix 27
# Multiplying matrix 28
# Multiplying matrix 29
# Multiplying matrix 30
# Multiplying matrix 31
# Multiplying matrix 32
# Multiplying matrix 33
# Multiplying matrix 34
# Multiplying matrix 35
# Multiplying matrix 36
# Multiplying matrix 37
# Multiplying matrix 38
# Multiplying matrix 39
# Multiplying matrix 40
# Multiplying matrix 41
# Multiplying matrix 42
# Multiplying matrix 43
# Multiplying matrix 44
# Multiplying matrix 45
# Multiplying matrix 46
# Multiplying matrix 47
# Multiplying matrix 48
# Multiplying matrix 49
# Multiplying matrix 50
# Multiplying matrix 51
# Multiplying matrix 52
# Multiplying matrix 53
# Multiplying matrix 54
# Multiplying matrix 55
# Multiplying matrix 56
# Multiplying matrix 57
# Multiplying matrix 58
# Multiplying matrix 59
# Multiplying matrix 60
# Multiplying matrix 61
# Multiplying matrix 62
# Multiplying matrix 63
# Multiplying matrix 64
# Multiplying matrix 65
# Multiplying matrix 66
# Multiplying matrix 67
# Multiplying matrix 68
# Multiplying matrix 69
# Multiplying matrix 70
# Multiplying matrix 71
# Multiplying matrix 72
# Multiplying matrix 73
# Multiplying matrix 74
# Multiplying matrix 75
# Multiplying matrix 76
# Multiplying matrix 77
# Multiplying matrix 78
# Multiplying matrix 79
# Multiplying matrix 80
# Multiplying matrix 81
# Multiplying matrix 82
# Multiplying matrix 83
# Multiplying matrix 84
# Multiplying matrix 85
# Multiplying matrix 86
# Multiplying matrix 87
# Multiplying matrix 88
# Multiplying matrix 89
# Multiplying matrix 90
# Multiplying matrix 91
# Multiplying matrix 92
# Multiplying matrix 93
# Multiplying matrix 94
# Multiplying matrix 95
# Multiplying matrix 96
# Multiplying matrix 97
# Multiplying matrix 98
# Multiplying matrix 99
# Multiplying matrix 100
#     Thread still running (left 9)...
#     Thread still running (left 3)...
#  All Thread ends
# Total Time 80.360300 sec
# Num of threads:  5
# Multiplying matrix 1
# Multiplying matrix 2
# Multiplying matrix 3
# Multiplying matrix 4
# Multiplying matrix 5
# Multiplying matrix 6
# Multiplying matrix 7
# Multiplying matrix 8
# Multiplying matrix 9
# Multiplying matrix 10
# Multiplying matrix 11
# Multiplying matrix 12
# Multiplying matrix 13
# Multiplying matrix 14
# Multiplying matrix 15
# Multiplying matrix 16
# Multiplying matrix 17
# Multiplying matrix 18
# Multiplying matrix 19
# Multiplying matrix 20
# Multiplying matrix 21
# Multiplying matrix 22
# Multiplying matrix 23
# Multiplying matrix 24
# Multiplying matrix 25
# Multiplying matrix 26
# Multiplying matrix 27
# Multiplying matrix 28
# Multiplying matrix 29
# Multiplying matrix 30
# Multiplying matrix 31
# Multiplying matrix 32
# Multiplying matrix 33
# Multiplying matrix 34
# Multiplying matrix 35
# Multiplying matrix 36
# Multiplying matrix 37
# Multiplying matrix 38
# Multiplying matrix 39
# Multiplying matrix 40
# Multiplying matrix 41
# Multiplying matrix 42
# Multiplying matrix 43
# Multiplying matrix 44
# Multiplying matrix 45
# Multiplying matrix 46
# Multiplying matrix 47
# Multiplying matrix 48
# Multiplying matrix 49
# Multiplying matrix 50
# Multiplying matrix 51
# Multiplying matrix 52
# Multiplying matrix 53
# Multiplying matrix 54
# Multiplying matrix 55
# Multiplying matrix 56
# Multiplying matrix 57
# Multiplying matrix 58
# Multiplying matrix 59
# Multiplying matrix 60
# Multiplying matrix 61
# Multiplying matrix 62
# Multiplying matrix 63
# Multiplying matrix 64
# Multiplying matrix 65
# Multiplying matrix 66
# Multiplying matrix 67
# Multiplying matrix 68
# Multiplying matrix 69
# Multiplying matrix 70
# Multiplying matrix 71
# Multiplying matrix 72
# Multiplying matrix 73
# Multiplying matrix 74
# Multiplying matrix 75
# Multiplying matrix 76
# Multiplying matrix 77
# Multiplying matrix 78
# Multiplying matrix 79
# Multiplying matrix 80
# Multiplying matrix 81
# Multiplying matrix 82
# Multiplying matrix 83
# Multiplying matrix 84
# Multiplying matrix 85
# Multiplying matrix 86
# Multiplying matrix 87
# Multiplying matrix 88
# Multiplying matrix 89
# Multiplying matrix 90
# Multiplying matrix 91
# Multiplying matrix 92
# Multiplying matrix 93
# Multiplying matrix 94
# Multiplying matrix 95
# Multiplying matrix 96
# Multiplying matrix 97
# Multiplying matrix 98
# Multiplying matrix 99
# Multiplying matrix 100
#     Thread still running (left 8)...
#     Thread still running (left 5)...
#     Thread still running (left 3)...
#  All Thread ends
# Total Time 80.016700 sec

# %%
print(timelist)
# Out:
# [111.3369, 106.3311, 89.4514, 85.0638, 83.0297, 80.5837, 80.5053, 80.8142, 82.8097, 80.3603, 80.0168]
